# %% [markdown]
# # 02. Download subtitles
# As mentioned in the first notebook, I wanted to see how recommendations based on the subtitles of movies would perform in comparison to the descriptions. For this purpose, I first had to download some subtitles, which will be the focus of this notebook.

# %%
import requests
import json
import imdb
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ## Get subsample from the original dataset
# We will use the API of [opensubtitles](https://www.opensubtitles.com/en) to download the corresponding subtitles to the movies in the dataset. Unfortunately there is a download limit of 1000 subtitles per day, which is why I decided to reduce the dataset to 2000 movies (simply for practical reasons, of course you could also download the subtitles for the whole dataset if you want to wait for 6 days).
#
# Initially, however, I have reduced the dataset to 2500 movies, as subtitles will not be available for some films (or at least not in english) - so the additional 500 movies serve as a buffer.

# %%
"""
#Load original dataset
df = pd.read_csv('data/netflix_titles.csv')
#Only keep movies, get rid of TV shows
df = df.loc[df['type'] == 'Movie'].reset_index(drop=True)
#only keep the columns we're interested in
df = df[['title','listed_in','director','cast','description']]
df
"""
# Out:
#                                  title  \
# 0                 Dick Johnson Is Dead
# 1     My Little Pony: A New Generation
# 2                              Sankofa
# 3                         The Starling
# 4                         Je Suis Karl
# ...                                ...
# 6126                           Zinzana
# 6127                            Zodiac
# 6128                        Zombieland
# 6129                              Zoom
# 6130                            Zubaan
#
#                                              listed_in  \
# 0                                        Documentaries
# 1                             Children & Family Movies
# 2     Dramas, Independent Movies, International Movies
# 3                                     Comedies, Dramas
# 4                         Dramas, International Movies
# ...                                                ...
# 6126           Dramas, International Movies, Thrillers
# 6127                    Cult Movies, Dramas, Thrillers
# 6128                           Comedies, Horror Movies
# 6129                Children & Family Movies, Comedies
# 6130    Dramas, International Movies, Music & Musicals
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 6126                Majid Al Ansari
# 6127                  David Fincher
# 6128                Ruben Fleischer
# 6129                   Peter Hewitt
# 6130                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 1     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4     Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 6126  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 6127  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 6128  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 6129  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 6130  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     Equestria's divided. But a bright-eyed hero be...
# 2     On a photo shoot in Ghana, an American model s...
# 3     A woman adjusting to life after a loss contend...
# 4     After most of her family is murdered in a terr...
# ...                                                 ...
# 6126  Recovering alcoholic Talal wakes up inside a s...
# 6127  A political cartoonist, a crime reporter and a...
# 6128  Looking to survive in a world taken over by zo...
# 6129  Dragged from civilian life, a former superhero...
# 6130  A scrappy but poor boy worms his way into a ty...
#
# [6131 rows x 5 columns]

# %%
"""
#get 2500 random movies from the dataset 
df = df.sample(2500)
#reset index
df.reset_index(drop=True,inplace=True)
#save as a new .csv file
df.to_csv('data/netflix_subsample.csv')
"""

# %%
#Load subsample df
df = pd.read_csv('data/netflix_subsample.csv')
df
# Out:
#                                                   title  \
# 0                                  The Last Blockbuster
# 1                 Franco Escamilla: Bienvenido al mundo
# 2                                          Last Knights
# 3                                            Win It All
# 4                                     Bewildered Bolbol
# ...                                                 ...
# 2495                                           Star Men
# 2496                       Tremors 4: The Legend Begins
# 2497                           Tottaa Pataaka Item Maal
# 2498                                            Koshish
# 2499  13TH: A Conversation with Oprah Winfrey & Ava ...
#
#                                              listed_in          director  \
# 0                                        Documentaries     Taylor Morden
# 1                                      Stand-Up Comedy   Ulises Valencia
# 2                                   Action & Adventure    Kazuaki Kiriya
# 3        Comedies, Independent Movies, Romantic Movies      Joe Swanberg
# 4      Comedies, International Movies, Romantic Movies      Khaled Marei
# ...                                                ...               ...
# 2495                                     Documentaries    Alison E. Rose
# 2496         Comedies, Horror Movies, Sci-Fi & Fantasy       S.S. Wilson
# 2497  Dramas, Independent Movies, International Movies  Aditya Kripalani
# 2498             International Movies, Romantic Movies            Gulzar
# 2499                                            Movies               NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1                                      Franco Escamilla
# 2     Clive Owen, Morgan Freeman, Cliff Curtis, Akse...
# 3     Jake Johnson, Aislinn Derbez, Joe Lo Truglio, ...
# 4     Ahmed Helmy, Zeina, Shery Adel, Emy Samir Ghan...
# ...                                                 ...
# 2495                                                NaN
# 2496  Michael Gross, Sara Botsford, Billy Drago, Bre...
# 2497  Shalini Vatsa, Chitrangada Chakraborty, Vinay ...
# 2498  Sanjeev Kumar, Jaya Bhaduri, Asrani, Seema, Om...
# 2499                        Oprah Winfrey, Ava DuVernay
#
#                                             description
# 0     This nostalgic documentary reveals the real st...
# 1     Comedian Franco Escamilla shares stories about...
# 2     A nobleman who values his people's well-being ...
# 3     After losing $50,000 that wasn't his, gambling...
# 4     A man suffering from amnesia can't seem to cho...
# ...                                                 ...
# 2495  Four astronomers from England celebrate 50 yea...
# 2496  Residents of a abandoned mining town attempt t...
# 2497  Exasperated with living in perpetual fear for ...
# 2498  A speech and hearing-impaired couple persists ...
# 2499  Oprah Winfrey sits down with director Ava DuVe...
#
# [2500 rows x 5 columns]

# %% [markdown]
# ## Get IMDb IDs for all movies
# To find the right movies via the opensubtitles API, we need a clear identifier for each movie: the IMDb-ID. This is simply an ID IMDb allocates to every movie on their website.
#
# For example, if the link to the movie is https://www.imdb.com/title/tt0241527/, the IMDb ID is 0241527.

# %%
#add empty columns to df to save the IDs later on
df['imdb_id'] = np.nan
df['opensubtitle_id'] = np.nan

# %%
#since the cell below timed out when searching for too many titles at once, I did it in parts
slice_start = 2400
slice_end = 2500

# %%
##The original code in this cell is from the user 'rakshitarora' on GeeksforGeeks (2020), 'Python IMDbPY – Getting movie ID from searched movies', link: https://www.geeksforgeeks.org/python-imdbpy-getting-movie-id-from-searched-movies/
## I modified it to work in a loop, save the ids to the df and added the if statements (to avoid errors & show if it couldn't find a movie)

#creating instance of IMDb
ia = imdb.IMDb()
not_found = []

for i, j in df[slice_start:slice_end].iterrows():
    #searching the name
    search = ia.search_movie(j['title'])
    if search:
        id = search[0].movieID #getting the id (modified to only get the first one)
        df.loc[i, 'imdb_id'] = id #add id to df
    elif not search: #movies it couldn't find
        print(j['title'])
# Out:
# Little Singham - Black Shadow
# Antariksha Ke Rakhwale

# %%
#show all rows in df where no imdb_id was found
#df[df['imdb_id'].isna()]
len(df[df['imdb_id'].isna()])
# Out:
# 23

# %%
#drop rows where no imdb_id was found
df = df.dropna(subset=['imdb_id']).reset_index(drop=True)

# %% [markdown]
# ## Download subtitles

# %% [markdown]
# Let's access opensubtitles to download the corresponding movie subtitles. To get the download link, we first need to get the opensubtitles file ID for each movie.
# > To be able to use the opensubtitles API, you need your own account details, API-Key & authorization token. I have deleted my personal information from the following code. Please reach out if you should need them.

# %%
##The code in this cell from user 'Birkan' on Stackoverflow (2021), 'How can we reach the information with the opensubtitles API?', link: https://stackoverflow.com/questions/66737712/how-can-we-reach-the-information-with-the-opensubtitles-api#comment118085673_66773501

#get the authorization token from opensubtitles (we need it later on to download the subtitles)
url = "https://api.opensubtitles.com/api/v1/login"
headers = {'Api-Key':'YOUR-KEY', 'Content-Type': 'application/json', 'Accept': "application/json"}
user = {'username': 'YOUR-USERNAME', 'password': "YOUR-PASSWORD"}

try:
    login_response = requests.post(url, data=json.dumps(user), headers=headers)
    login_response.raise_for_status()
    login_json_response = login_response.json()
    login_token = login_json_response['token'] #authorization token
except:
    print("Something wrong check again...")

# %%
##The code in this cell from user 'Birkan' on Stackoverflow (2021), 'How can we reach the information with the opensubtitles API?', link: https://stackoverflow.com/questions/66737712/how-can-we-reach-the-information-with-the-opensubtitles-api#comment118085673_66773501
##I modified it to work in a loop, save the id to the df and added the if-else statement

#get opensubtitles file id with the help of the imdb id

language="en"
headers = {
        'Api-Key': 'YOUR-KEY',
    }

for i, j in df.iterrows():
    query_response = requests.get('https://api.opensubtitles.com/api/v1/subtitles?imdb_id='+j['imdb_id']+'&languages='+language, headers=headers)
    query_json_response = query_response.json()
    #The if-else statement was added to avoid errors when no subtitles were found
    if query_json_response['total_pages'] >= 1:
        query_file_no = query_json_response['data'][0]['attributes']['files'][0]['file_id']
        #print("Subtitles found for: ", movie_titles[i], "; File Number:",query_file_no)
        df.loc[i, 'opensubtitle_id'] = query_file_no
    else:
        print("No subtitles found for: ", j['title'])
# Out:
# No subtitles found for:  Bewildered Bolbol
# No subtitles found for:  Prince of Peoria: A Christmas Moose Miracle
# No subtitles found for:  The Loud House Movie
# No subtitles found for:  Coco y Raulito: Carrusel de ternura
# No subtitles found for:  Be Somebody
# No subtitles found for:  Raya and Sakina
# No subtitles found for:  Hajwala: The Missing Engine
# No subtitles found for:  Bill Hicks: Reflections
# No subtitles found for:  Mama Drama
# No subtitles found for:  Todd Barry: Spicy Honey
# No subtitles found for:  Bhouri
# No subtitles found for:  Amit Tandon: Family Tandoncies
# No subtitles found for:  Motor Mitraan Di
# No subtitles found for:  The Killer
# No subtitles found for:  Locked on You
# No subtitles found for:  Killers
# No subtitles found for:  Qismat
# No subtitles found for:  Jerry Seinfeld: Comedian
# No subtitles found for:  Blade Runner: The Final Cut
# No subtitles found for:  Late Life: The Chien-Ming Wang Story
# No subtitles found for:  Francesco De Carlo: Cose di Questo Mondo
# No subtitles found for:  14 Minutes from Earth
# No subtitles found for:  Fishtail
# No subtitles found for:  Love Is War
# No subtitles found for:  Chhota Bheem and the Incan Adventure
# No subtitles found for:  Food on the Go
# No subtitles found for:  Fanatyk
# No subtitles found for:  It's Okay, Buddy
# No subtitles found for:  The Tigers of Scotland
# No subtitles found for:  Luccas Neto in: Summer Camp
# No subtitles found for:  The Drowning
# No subtitles found for:  The Pirates! Band of Misfits
# No subtitles found for:  Motu Patlu in Dragon's World
# No subtitles found for:  Tim Allen: Men Are Pigs
# No subtitles found for:  Chelsea Peretti: One of the Greats
# No subtitles found for:  Chhota Bheem: Dholakpur to Kathmandu
# No subtitles found for:  Mark Gatiss: A Study in Sherlock
# No subtitles found for:  Dil Vil Pyaar Vyaar
# No subtitles found for:  StarBeam: Halloween Hero
# No subtitles found for:  Mobile Suit Gundam I
# No subtitles found for:  Darra
# No subtitles found for:  David Batra: Elefanten i rummet
# No subtitles found for:  Dark City Beneath the Beat
# No subtitles found for:  100 Years: One Woman's Fight for Justice
# No subtitles found for:  The Young Offenders
# No subtitles found for:  Dolly Parton’s Christmas on the Square
# No subtitles found for:  Sorry To Disturb
# No subtitles found for:  Sayed the Servant
# No subtitles found for:  The Massively Mixed-Up Middle School Mystery
# No subtitles found for:  Colin Quinn: Unconstitutional
# No subtitles found for:  My True Friend
# No subtitles found for:  Diamonds in the Sky
# No subtitles found for:  #Selfie
# No subtitles found for:  Alan Saldaña: Mi vida de pobre
# No subtitles found for:  Pee-wee's Playhouse: Christmas Special
# No subtitles found for:  Alexis Viera: A Story of Surviving
# No subtitles found for:  Boomika (Malayalam)
# No subtitles found for:  Merata: How Mum Decolonised the Screen
# No subtitles found for:  Krish Trish and Baltiboy: The Greatest Trick
# No subtitles found for:  Fred Armisen: Standup For Drummers
# No subtitles found for:  Jora 10 Numbaria
# No subtitles found for:  Guy Martin: Last Flight of the Vulcan Bomber
# No subtitles found for:  Kacche Dhaagey
# No subtitles found for:  NOVA: Killer Floods
# No subtitles found for:  Table Manners
# No subtitles found for:  Ghulam-E-Musthafa
# No subtitles found for:  Aisa Yeh Jahaan
# No subtitles found for:  Firedrake the Silver Dragon
# No subtitles found for:  The School of Mischief
# No subtitles found for:  Tayo the Little Bus Movie: Mission Ace
# No subtitles found for:  Shadow Parties
# No subtitles found for:  Barrio Universitario
# No subtitles found for:  Super Monsters: Vida's First Halloween
# No subtitles found for:  Tiffany Haddish: Black Mitzvah
# No subtitles found for:  Master
# No subtitles found for:  ChuChuTV Bedtime Stories & Moral Stories for Kids (English)
# No subtitles found for:  Bawarchi
# No subtitles found for:  The Price of Success
# No subtitles found for:  Motu Patlu: Mission Moon
# No subtitles found for:  The Strange House
# No subtitles found for:  Bratz: The Movie
# No subtitles found for:  Leo the Lion
# No subtitles found for:  Shikari
# No subtitles found for:  Sameer Abu Alneel
# No subtitles found for:  Vampire Academy
# No subtitles found for:  Saverio Raimondo: Il Satiro Parlante
# No subtitles found for:  Eerie
# No subtitles found for:  Namak Halaal
# No subtitles found for:  Si Doel the Movie 2
# No subtitles found for:  Omar & Salma 2
# No subtitles found for:  Jackpot
# No subtitles found for:  Best Wishes, Warmest Regards: A Schitt's Creek Farewell
# No subtitles found for:  Meet the In-Laws
# No subtitles found for:  Dhoondte Reh Jaoge
# No subtitles found for:  Hitler's Olympics
# No subtitles found for:  Theo Who Lived
# No subtitles found for:  Victor
# No subtitles found for:  Power Rangers: Megaforce: Raising Spirits
# No subtitles found for:  Yo-Kai Watch: The Movie
# No subtitles found for:  Teen Aur Aadha
# No subtitles found for:  What the Fish
# No subtitles found for:  Something Huge
# No subtitles found for:  Chhota Bheem and the Curse of Damyaan
# No subtitles found for:  9
# No subtitles found for:  Shiva: Journey to Plunotaria
# No subtitles found for:  River, el más grande siempre
# No subtitles found for:  Thottappan
# No subtitles found for:  Elaan
# No subtitles found for:  GIMS: On the Record
# No subtitles found for:  Invisible Essence: The Little Prince
# No subtitles found for:  Shakti: The Power
# No subtitles found for:  Khubsoorat
# No subtitles found for:  Ken Jeong: You Complete Me, Ho
# No subtitles found for:  Out of Many, One
# No subtitles found for:  Onaatah
# No subtitles found for:  Teenage Mutant Ninja Turtles
# No subtitles found for:  A Family Affair
# No subtitles found for:  The Beginning of Life
# No subtitles found for:  3 Türken & ein Baby
# No subtitles found for:  Chhota Bheem aur Krishna
# No subtitles found for:  Karkar
# No subtitles found for:  Once In A Lifetime Sessions with Moby
# No subtitles found for:  Surviving R. Kelly: The Impact
# No subtitles found for:  Ibrahim a Fate to Define
# No subtitles found for:  Christmas in the Heartland
# No subtitles found for:  Galih dan Ratna
# No subtitles found for:  Acapulco La vida va
# No subtitles found for:  Saavat
# No subtitles found for:  Lechmi
# No subtitles found for:  The Workshop
# No subtitles found for:  Todd Glass: Stand-Up Special
# No subtitles found for:  Euphoria
# No subtitles found for:  Kanika
# No subtitles found for:  Rainbow Jelly
# No subtitles found for:  Skydancers
# No subtitles found for:  Meet the Trumps: From Immigrant to President
# No subtitles found for:  André & his olive tree
# No subtitles found for:  Sillu Karuppatti
# No subtitles found for:  Swearnet Live
# No subtitles found for:  In Our Mothers' Gardens
# No subtitles found for:  Chhota Bheem: Master of Shaolin
# No subtitles found for:  When Hari Got Married
# No subtitles found for:  From One Second to the Next
# No subtitles found for:  Hank: Five Years from the Brink
# No subtitles found for:  Drink Drank Drunk
# No subtitles found for:  Concrete Football
# No subtitles found for:  Bibi & Tina: Tohuwabohu Total
# No subtitles found for:  DNA
# No subtitles found for:  Famous in Ahmedabad
# No subtitles found for:  The Beach Loafer
# No subtitles found for:  Howards End
# No subtitles found for:  One Day: Justice Delivered
# No subtitles found for:  Know Your Enemy - Japan
# No subtitles found for:  The Light of My Eyes
# No subtitles found for:  Chippa
# No subtitles found for:  Thug Life
# No subtitles found for:  Eeb Allay Ooo!
# No subtitles found for:  Bodyguard
# No subtitles found for:  Ek Khiladi Ek Haseena
# No subtitles found for:  Three-Quarters Decent
# No subtitles found for:  Freeway: Crack in the System
# No subtitles found for:  Talentime
# No subtitles found for:  Magnetic
# No subtitles found for:  The Gospel of Luke
# No subtitles found for:  Shahanpan Dega Deva
# No subtitles found for:  Seven Souls in the Skull Castle: Season Wind
# No subtitles found for:  Clarence Clemons: Who Do I Think I Am?
# No subtitles found for:  Santa Pac's Merry Berry Day
# No subtitles found for:  Chhota Bheem Aur Hanuman
# No subtitles found for:  One Heart: The A.R. Rahman Concert Film
# No subtitles found for:  Therapy
# No subtitles found for:  A Witches' Ball
# No subtitles found for:  The Creative Brain
# No subtitles found for:  Mandobasar Galpo
# No subtitles found for:  Monster High: Fright On!
# No subtitles found for:  NOVA: Thai Cave Rescue
# No subtitles found for:  The Lincoln Lawyer
# No subtitles found for:  To and From New York
# No subtitles found for:  The Devil's Mistress
# No subtitles found for:  No Longer kids
# No subtitles found for:  Wave of Cinema: Filosofi Kopi
# No subtitles found for:  Poms
# No subtitles found for:  Discovering Bigfoot
# No subtitles found for:  Our House
# No subtitles found for:  Anthony Jeselnik: Fire in the Maternity Ward
# No subtitles found for:  Splatter
# No subtitles found for:  Loyiso Gola: Unlearning
# No subtitles found for:  Cycle
# No subtitles found for:  Stunt School
# No subtitles found for:  Belmonte
# No subtitles found for:  Brian Regan: On the Rocks
# No subtitles found for:  Chandani: The Daughter of the Elephant Whisperer
# No subtitles found for:  Players
# No subtitles found for:  Lucha: Playing the Impossible
# No subtitles found for:  Todo lo que sería Lucas Lauriente
# No subtitles found for:  Girls und Panzer der Film
# No subtitles found for:  The Last Days of Chez Nous
# No subtitles found for:  I Am
# No subtitles found for:  Bling Empire - The Afterparty
# No subtitles found for:  Arango y Sanint: Ríase el show
# No subtitles found for:  The Time Traveler's Wife
# No subtitles found for:  15 August
# No subtitles found for:  Temple
# No subtitles found for:  Trailer Park Boys Live at the North Pole
# No subtitles found for:  SunGanges
# No subtitles found for:  Ethirmarai
# No subtitles found for:  Pedal the World
# No subtitles found for:  Ek Cup Chya
# No subtitles found for:  Sommore: The Reign Continues
# No subtitles found for:  Heroin(e)
# No subtitles found for:  World's Weirdest Homes
# No subtitles found for:  Sinister Circle
# No subtitles found for:  Mike Birbiglia: What I Should Have Said Was Nothing: Tales from My Secret Public Journal
# No subtitles found for:  Fernando Sanjiao: Hombre
# No subtitles found for:  Seven Souls in the Skull Castle: Season Moon Jogen
# No subtitles found for:  Monty Python's Life of Brian
# No subtitles found for:  Turkish Dance School
# No subtitles found for:  Macchli Jal Ki Rani Hai
# No subtitles found for:  One Last Shot
# No subtitles found for:  The Bad Batch
# No subtitles found for:  Tee Shot: Ariya Jutanugarn
# No subtitles found for:  Rhys Nicholson Live at the Athenaeum
# No subtitles found for:  What Makes a Psychopath?
# No subtitles found for:  Dream Boat
# No subtitles found for:  Legal Hash
# No subtitles found for:  Yoo Byung Jae: Discomfort Zone
# No subtitles found for:  How to Stage a Coup
# No subtitles found for:  Fukrey Boyzzz: Space Mein Fukrapanti
# No subtitles found for:  Power Rangers Samurai: Christmas Together, Friends Forever (Christmas Special)
# No subtitles found for:  Oh! Baby (Malayalam)
# No subtitles found for:  Naruto the Movie: Ninja Clash in the Land of Snow
# No subtitles found for:  The Royal Hibiscus Hotel
# No subtitles found for:  Little Baby Bum: Go Buster
# No subtitles found for:  187
# No subtitles found for:  The American
# No subtitles found for:  Resurface
# No subtitles found for:  Black Snow
# No subtitles found for:  Uriyadi 2
# No subtitles found for:  The Tree of Blood
# No subtitles found for:  How to Get Over a Breakup
# No subtitles found for:  Two Catalonias
# No subtitles found for:  Bigflo & Oli: Hip Hop Frenzy
# No subtitles found for:  The Tambour of Retribution
# No subtitles found for:  Pandigai
# No subtitles found for:  Jake's Buccaneer Blast
# No subtitles found for:  Chhota Bheem in African Safari
# No subtitles found for:  Kitty Love: An Homage to Cats
# No subtitles found for:  Holy Expectations
# No subtitles found for:  Septiembre, un llanto en silencio
# No subtitles found for:  Who's That Knocking at My Door?
# No subtitles found for:  Moon
# No subtitles found for:  The Real Miyagi
# No subtitles found for:  Chaotic Love Poems
# No subtitles found for:  Marco Polo: One Hundred Eyes
# No subtitles found for:  Badha
# No subtitles found for:  Across Grace Alley
# No subtitles found for:  The Forbidden Kingdom
# No subtitles found for:  Tango Feroz
# No subtitles found for:  Tyson
# No subtitles found for:  Blitz Patrollie
# No subtitles found for:  40 Sticks
# No subtitles found for:  Russell Howard: Recalibrate
# No subtitles found for:  Catwalk: Tales from the Cat Show Circuit
# No subtitles found for:  Mom
# No subtitles found for:  Interview with a Serial Killer
# No subtitles found for:  Bhasmasur
# No subtitles found for:  LEGENDS OF THE HIDDEN TEMPLE
# No subtitles found for:  Monster High: Friday Night Frights
# No subtitles found for:  Sons of Ben
# No subtitles found for:  From Stress to Happiness
# No subtitles found for:  Last Summer
# No subtitles found for:  Melle
# No subtitles found for:  Alakada Reloaded
# No subtitles found for:  God Calling
# No subtitles found for:  The End of Evangelion
# No subtitles found for:  Maacher Jhol
# No subtitles found for:  Muzaffarnagar Baaqi Hai
# No subtitles found for:  My Step Dad: The Hippie
# No subtitles found for:  Haseena Maan Jaayegi
# No subtitles found for:  Simplemente Manu NNa
# No subtitles found for:  EMI: Liya Hai To Chukana Padega
# No subtitles found for:  Daniel Sosa: Sosafado
# No subtitles found for:  Horror Story
# No subtitles found for:  Love Station
# No subtitles found for:  Irada Pakka
# No subtitles found for:  Chingo Bling: They Can't Deport Us All
# No subtitles found for:  Super Monsters Save Christmas
# No subtitles found for:  Pablo Escobar: Angel or Demon?
# No subtitles found for:  Print the Legend
# No subtitles found for:  Rajnigandha
# No subtitles found for:  Lagos Real Fake Life
# No subtitles found for:  The Ant's Scream
# No subtitles found for:  We'll Be Right Back After The Break
# No subtitles found for:  Kalakalappu
# No subtitles found for:  Monty Python: Before the Flying Circus
# No subtitles found for:  The Tour
# No subtitles found for:  The Girl and the Gun
# No subtitles found for:  Holy Man 3
# No subtitles found for:  Sofía Niño de Rivera: Selección Natural
# No subtitles found for:  Mariah Carey's Merriest Christmas
# No subtitles found for:  Franca: Chaos and Creation
# No subtitles found for:  Love O2O
# No subtitles found for:  S Is for Stanley
# No subtitles found for:  The Boys in the Band: Something Personal
# No subtitles found for:  Project Marathwada
# No subtitles found for:  Wonho Chung: Live in New York
# No subtitles found for:  Samarppanam
# No subtitles found for:  Eggnoid: Love & Time Portal
# No subtitles found for:  Miracle
# No subtitles found for:  Zulu Man in Japan
# No subtitles found for:  Oddbods: The Festive Menace
# No subtitles found for:  Legion
# No subtitles found for:  Lalbaug Parel: Zali Mumbai Sonyachi
# No subtitles found for:  Confusion Na Wa
# No subtitles found for:  Maya Angelou: And Still I Rise
# No subtitles found for:  Starsky & Hutch
# No subtitles found for:  Lock Your Girls In
# No subtitles found for:  Prosecuting Evil: The Extraordinary World of Ben Ferencz
# No subtitles found for:  Stretch Armstrong: The Breakout
# No subtitles found for:  The Tourist
# No subtitles found for:  Fatso
# No subtitles found for:  Giving Voice
# No subtitles found for:  Krish Trish and Baltiboy: Battle of Wits
# No subtitles found for:  Ideachi Kalpana
# No subtitles found for:  Mumbai Matinee
# No subtitles found for:  GODZILLA City on the Edge of Battle
# No subtitles found for:  Leap!
# No subtitles found for:  Aadu 2
# No subtitles found for:  Secrets of the Tower of London
# No subtitles found for:  Danny Says
# No subtitles found for:  El Che
# No subtitles found for:  Radiopetti
# No subtitles found for:  #Rucker50
# No subtitles found for:  John & Jane
# No subtitles found for:  Trailer Park Boys Live In F**kin' Dublin
# No subtitles found for:  Larceny
# No subtitles found for:  Ahaan
# No subtitles found for:  Cracked Up: The Darrell Hammond Story
# No subtitles found for:  Stealing History
# No subtitles found for:  Anthony Kaun Hai?
# No subtitles found for:  Motu Patlu in Octupus World
# No subtitles found for:  Justin Timberlake + the Tennessee Kids
# No subtitles found for:  A StoryBots Space Adventure
# No subtitles found for:  The International Player
# No subtitles found for:  The Outsider
# No subtitles found for:  Tellur Aliens
# No subtitles found for:  Papa the Great
# No subtitles found for:  Don't Crack Under Pressure
# No subtitles found for:  Natalia Valdebenito: Gritona
# No subtitles found for:  INDIA
# No subtitles found for:  Kaleidoscope
# No subtitles found for:  Behind "The Cove": The Quiet Japanese Speak Out
# No subtitles found for:  Mobile Suit Gundam II: Soldiers of Sorrow
# No subtitles found for:  Jatts in Golmaal
# No subtitles found for:  Settai
# No subtitles found for:  Deadline: Sirf 24 Ghante
# No subtitles found for:  Jack of all Trades
# No subtitles found for:  A Kid from Coney Island
# No subtitles found for:  Siren
# No subtitles found for:  Secrets of Althorp - The Spencers
# No subtitles found for:  Aajcha Divas Majha
# No subtitles found for:  Virunga: Gorillas in Peril
# No subtitles found for:  Surga Yang Tak Dirindukan
# No subtitles found for:  The Vendor
# No subtitles found for:  Deathgrip
# No subtitles found for:  The Jungle School
# No subtitles found for:  The Dealer
# No subtitles found for:  Ascharyachakit!
# No subtitles found for:  7 Din Mohabbat In
# No subtitles found for:  Chadi Jawani Budhe Nu
# No subtitles found for:  Chris D'Elia: Incorrigible
# No subtitles found for:  Seven (Telugu)
# No subtitles found for:  Muran
# No subtitles found for:  The Starling
# No subtitles found for:  Dries
# No subtitles found for:  Mantostaan
# No subtitles found for:  The Great Hack
# No subtitles found for:  Candyflip
# No subtitles found for:  Barry
# No subtitles found for:  Bad Rap
# No subtitles found for:  The Monster of Mangatiti
# No subtitles found for:  Uncle Naji in UAE
# No subtitles found for:  Jhankaar Beats
# No subtitles found for:  True: Happy Hearts Day
# No subtitles found for:  Iyore
# No subtitles found for:  Gad Elmaleh: American Dream
# No subtitles found for:  Cahaya Dari Timur Beta Maluku
# No subtitles found for:  The Netflix Afterparty: The Best Shows of The Worst Year
# No subtitles found for:  LeapFrog: Numberland
# No subtitles found for:  Manolo: The Boy Who Made Shoes for Lizards
# No subtitles found for:  Rats
# No subtitles found for:  The C Word
# No subtitles found for:  Kaviyude Osyath
# No subtitles found for:  Seven and a half dates
# No subtitles found for:  Schubert In Love
# No subtitles found for:  Cézanne et moi
# No subtitles found for:  Ari Eldjárn: Pardon My Icelandic
# No subtitles found for:  Dave Chappelle: The Kennedy Center Mark Twain Prize for American Humor
# No subtitles found for:  KL Zombi
# No subtitles found for:  Who the F**k Is That Guy?
# No subtitles found for:  Antar: Son of Shadad
# No subtitles found for:  The Rift: The Dark Side of the Moon
# No subtitles found for:  Frozen Planet: On Thin Ice
# No subtitles found for:  Snowpiercer
# No subtitles found for:  Black
# No subtitles found for:  Tattah
# No subtitles found for:  Choked: Paisa Bolta Hai
# No subtitles found for:  Chicken Kokkachi
# No subtitles found for:  Beyond the Boundary: ICC Women's T20 World Cup Australia 2020
# No subtitles found for:  Omar and Salma 3
# No subtitles found for:  Wives on Strike
# No subtitles found for:  Bert Kreischer: The Machine
# No subtitles found for:  Beirut Oh Beirut
# No subtitles found for:  LeapFrog: Phonics Farm
# No subtitles found for:  Shadow
# No subtitles found for:  Bollywood Calling
# No subtitles found for:  A Way Back Home
# No subtitles found for:  Brother Jekwu
# No subtitles found for:  Flimflam
# No subtitles found for:  Little Lunch: The Halloween Horror Story
# No subtitles found for:  Trikal (Past, Present, Future)
# No subtitles found for:  Ragini MMS
# No subtitles found for:  Lessons from a School Shooting: Notes from Dunblane
# No subtitles found for:  Ek Hasina Thi
# No subtitles found for:  American Masters: Ted Williams
# No subtitles found for:  Colkatay Columbus
# No subtitles found for:  Bibi & Tina II
# No subtitles found for:  Carmen Sandiego: To Steal or Not to Steal
# No subtitles found for:  Bitch
# No subtitles found for:  This Is the Life
# No subtitles found for:  Interrogation
# No subtitles found for:  The Man Who Would Be Polka King
# No subtitles found for:  Freej Al Taibeen
# No subtitles found for:  Roll Red Roll
# No subtitles found for:  An American in Madras
# No subtitles found for:  Smash: Motorized Mayhem
# No subtitles found for:  True: Rainbow Rescue
# No subtitles found for:  Seven Souls in the Skull Castle: Season Bird
# No subtitles found for:  Jen Kirkman: I'm Gonna Die Alone (And I Feel Fine)
# No subtitles found for:  Emicida: AmarElo - Live in São Paulo
# No subtitles found for:  Little Miss Sumo
# No subtitles found for:  Chal Dhar Pakad
# No subtitles found for:  Chhota Bheem: The Rise of Kirmada
# No subtitles found for:  Roll With Me
# No subtitles found for:  Gardeners of Eden
# No subtitles found for:  NOVA: Holocaust Escape Tunnel
# No subtitles found for:  Empire of Scents
# No subtitles found for:  Once In A Lifetime Sessions with TLC
# No subtitles found for:  Kuldip Patwal: I Didn't Do It!
# No subtitles found for:  Marvel & ESPN Films Present: 1 of 1: Genesis
# No subtitles found for:  Hridaynath
# No subtitles found for:  Willy and the Guardians of the Lake: Tales from the Lakeside Winter Adventure
# No subtitles found for:  Sarivar Sari
# No subtitles found for:  Buddy Thunderstruck: The Maybe Pile
# No subtitles found for:  Sohni Mahiwal
# No subtitles found for:  Kyo Kii... Main Jhuth Nahin Bolta
# No subtitles found for:  I'm Glad I Did
# No subtitles found for:  What the F* Is Going On?
# No subtitles found for:  Ghost Whispers
# No subtitles found for:  Geez & Ann
# No subtitles found for:  Seven (Tamil)
# No subtitles found for:  Blind Intersections
# No subtitles found for:  My Wife and My Wifey
# No subtitles found for:  Aalorukkam
# No subtitles found for:  Anarkali of Aarah
# No subtitles found for:  LEGO Marvel Super Heroes: Guardians of the Galaxy
# No subtitles found for:  Krish Trish and Baltiboy: Part II
# No subtitles found for:  Babamın Ceketi
# No subtitles found for:  Ali & Alia
# No subtitles found for:  God Knows Where I Am
# No subtitles found for:  Morya
# No subtitles found for:  Rising Phoenix
# No subtitles found for:  Alpha and Omega: The Legend of the Saw Tooth Cave
# No subtitles found for:  A 3 Minute Hug
# No subtitles found for:  Here Comes the Rain
# No subtitles found for:  The Present
# No subtitles found for:  Celluloid Man
# No subtitles found for:  Rafinha Bastos: Ultimatum
# No subtitles found for:  Secrets of Selfridges
# No subtitles found for:  From Japan to Egypt
# No subtitles found for:  Luciano Mellera: Infantiloide
# No subtitles found for:  Freezer's Campaign
# No subtitles found for:  My Only Mother
# No subtitles found for:  Maynard
# No subtitles found for:  NOVA: Prediction by the Numbers
# No subtitles found for:  Speed Is My Need
# No subtitles found for:  A Holiday Engagement
# No subtitles found for:  Power Rangers Super Samurai: Trickster Treat
# No subtitles found for:  Dear Dad
# No subtitles found for:  Mad Ron's Prevues from Hell
# No subtitles found for:  Fabrizio Copano: Solo pienso en mi
# No subtitles found for:  American Factory: A Conversation with the Obamas
# No subtitles found for:  Bob's Broken Sleigh
# No subtitles found for:  Motu Patlu in the Game of Zones
# No subtitles found for:  Seven Souls in the Skull Castle: Season Flower
# No subtitles found for:  Besieged Bread
# No subtitles found for:  The Damned Rain
# No subtitles found for:  Mighty Raju Rio Calling
# No subtitles found for:  Abhinetri
# No subtitles found for:  Brian Regan: Nunchucks and Flamethrowers
# No subtitles found for:  Maddman: The Steve Madden Story
# No subtitles found for:  Mi Shivajiraje Bhosale Boltoy
# No subtitles found for:  Cold Harbour
# No subtitles found for:  Gina Yashere: Laughing to America
# No subtitles found for:  Maroon
# No subtitles found for:  Before the Summer Crowds
# No subtitles found for:  Oct-01
# No subtitles found for:  American Circumcision
# No subtitles found for:  Thomas & Friends: Marvelous Machinery: A New Arrival
# No subtitles found for:  Dad Stop Embarrassing Me - The Afterparty
# No subtitles found for:  History of Joy
# No subtitles found for:  Misfit 2
# No subtitles found for:  Sigaram Thodu
# No subtitles found for:  Beauties of the Night
# No subtitles found for:  99 Songs (Telugu)
# No subtitles found for:  Kurbaan
# No subtitles found for:  Pekak
# No subtitles found for:  Saawan
# No subtitles found for:  Dr. Seuss' The Cat in the Hat
# No subtitles found for:  Soul Robbers
# No subtitles found for:  For Here or to Go?
# No subtitles found for:  Pocoyo & Cars
# No subtitles found for:  Saudi Arabia Uncovered
# No subtitles found for:  Beyond All Boundaries
# No subtitles found for:  Tamanchey
# No subtitles found for:  Warda
# No subtitles found for:  Adel Karam: Live from Beirut
# No subtitles found for:  Jeff Garlin: Our Man In Chicago
# No subtitles found for:  High End Yaariyan
# No subtitles found for:  Submission
# No subtitles found for:  What a Wonderful Family!
# No subtitles found for:  Apaharan
# No subtitles found for:  Force 2
# No subtitles found for:  Once Upon a Time in the West
# No subtitles found for:  Die Ontwaking
# No subtitles found for:  Bugs
# No subtitles found for:  NOVA: Black Hole Apocalypse
# No subtitles found for:  Avvai Shanmughi
# No subtitles found for:  Chhota Bheem and The ShiNobi Secret
# No subtitles found for:  Pop, Lock 'n Roll
# No subtitles found for:  Nee Enge En Anbe
# No subtitles found for:  Firebrand
# No subtitles found for:  D.L. Hughley: Clear
# No subtitles found for:  Christmas with a Prince
# No subtitles found for:  Harry Benson: Shoot First
# No subtitles found for:  Kandasamys: The Wedding
# No subtitles found for:  Secrets of Westminster
# No subtitles found for:  Fat Ballerina - David A. Arnold
# No subtitles found for:  Mugamoodi
# No subtitles found for:  The Last Kids on Earth: Happy Apocalypse to You
# No subtitles found for:  Kung Fu Magoo
# No subtitles found for:  War Against Women
# No subtitles found for:  Best Neighbors
# No subtitles found for:  Jenny Slate: Stage Fright
# No subtitles found for:  Virsa
# No subtitles found for:  Ralphie May: Unruly
# No subtitles found for:  BoJack Horseman Christmas Special: Sabrina's Christmas Wish
# No subtitles found for:  Growing Up Coy
# No subtitles found for:  Amar Akbar & Tony
# No subtitles found for:  Cold Feet
# No subtitles found for:  Tim Minchin: So F**king Rock
# No subtitles found for:  Ralph Breaks the Internet: Wreck-It Ralph 2
# No subtitles found for:  Marco Luque: Tamo Junto
# No subtitles found for:  Calico Critters: The Treasure of Calico Village
# No subtitles found for:  The Beginning of Life 2: Outside
# No subtitles found for:  ReMastered: Massacre at the Stadium
# No subtitles found for:  Adrishya
# No subtitles found for:  Sex and the City: The Movie
# No subtitles found for:  Doom
# No subtitles found for:  House of Z
# No subtitles found for:  Tottaa Pataaka Item Maal
# No subtitles found for:  Koshish
# No subtitles found for:  13TH: A Conversation with Oprah Winfrey & Ava DuVernay

# %%
#For how many movies were no subtitles found?
len(df[df['opensubtitle_id'].isna()])
# Out:
# 573

# %%
#drop rows where no subtitles were found
df = df.dropna(subset=['opensubtitle_id']).reset_index(drop=True)

# %%
#1904 movies left from the 2500 we started with
len(df)
# Out:
# 1904

# %%
##The code in this cell from user 'Birkan' on Stackoverflow (2021), 'How can we reach the information with the opensubtitles API?', link: https://stackoverflow.com/questions/66737712/how-can-we-reach-the-information-with-the-opensubtitles-api#comment118085673_66773501
##I modified it to work in a loop (and with my df)

#Get the download url for the subtitles & download the file

#API URL and authorization
download_url = "https://api.opensubtitles.com/api/v1/download"
download_headers = {'api-key': 'YOUR-KEY',
                    'authorization':"Bearer "+login_token,
                    'content-type': 'application/json'}

#iterate over the df and download the subtitles
for i, j in df[1000:1904].iterrows():
    download_file_id = {'file_id': j['opensubtitle_id']} #get the opensubtitles file id from the df
    download_response = requests.post(download_url, data=json.dumps(download_file_id), headers=download_headers)
    download_json_response = download_response.json()
    print("Report:",download_response)
    print(download_json_response)

    link=download_json_response['link'] #get the download link
    saved_file_name = "data/subtitles_download/"+ j['title'] +".txt" #give the file the title of the movie
    r = requests.get(link)
    with open(saved_file_name, 'wb') as f:
        f.write(r.content) #save the file
# Out:
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....-dvdivx-fmi1.srt', 'file_name': 'jn-dvdivx-fmi1.srt', 'requests': 217, 'remaining': 783, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648978 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648978}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Of.The.Dragon.2016.720p.BluRay.x264-GECKOS-HI.srt', 'file_name': 'Birth.Of.The.Dragon.2016.720p.BluRay.x264-GECKOS-HI.srt', 'requests': 218, 'remaining': 782, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648979 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648979}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Smurfs.2011.BRRip.XviD-LTRG.srt', 'file_name': 'The.Smurfs.2011.BRRip.XviD-LTRG.srt', 'requests': 219, 'remaining': 781, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648979 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648979}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....A.Star.Wars.Story.2018.720p.BluRay.x264.DTS-HDC.srt', 'file_name': 'Solo.A.Star.Wars.Story.2018.720p.BluRay.x264.DTS-HDC.srt', 'requests': 220, 'remaining': 780, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648980 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648980}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Todd-The.Demon.Barber.Of.Fleet.Street%5B2007%5DDvDrip%5BEng%5D-aXXo.en.srt', 'file_name': 'Sweeney.Todd-The.Demon.Barber.Of.Fleet.Street[2007]DvDrip[Eng]-aXXo.en.srt', 'requests': 221, 'remaining': 779, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648980 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648980}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20-%2044x02%20-%20School%20of%20the%20Future.Unspecified.srt', 'file_name': 'NOVA - 44x02 - School of the Future.Unspecified.srt', 'requests': 222, 'remaining': 778, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648981 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648981}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Of.The.Galaxy.Volume.3.2023.ENG.HDTC.1080p.x264.AAC-HushRips.srt', 'file_name': 'Guardian.Of.The.Galaxy.Volume.3.2023.ENG.HDTC.1080p.x264.AAC-HushRips.srt', 'requests': 222, 'remaining': 778, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648981 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648981}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Ek.Prem.Katha.2017.Hindi.720p.BDRip.x264.AAC.1.4GB-ESubs-TamilRockers.mx.srt', 'file_name': 'Toilet.Ek.Prem.Katha.2017.Hindi.720p.BDRip.x264.AAC.1.4GB-ESubs-TamilRockers.mx.srt', 'requests': 223, 'remaining': 777, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648982 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648982}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....World.2016.720p.BluRay.x264-ROVERS.srt', 'file_name': 'Ordinary.World.2016.720p.BluRay.x264-ROVERS.srt', 'requests': 224, 'remaining': 776, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648982 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648982}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20chup%20ke%202006.avi.srt', 'file_name': 'chup chup ke 2006.avi.srt', 'requests': 225, 'remaining': 775, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648982 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648982}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....It.Up.2018.WEBRip.x264-STRiFE.srt', 'file_name': 'Set.It.Up.2018.WEBRip.x264-STRiFE.srt', 'requests': 226, 'remaining': 774, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648983 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648983}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20Hallows%20Eve%5B2013%5D%20HDRip%20XViD-ETRG.srt', 'file_name': 'All Hallows Eve[2013] HDRip XViD-ETRG.srt', 'requests': 227, 'remaining': 773, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648983 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648983}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20Meng%20Hua%20-%20Flying%20guillotine%20english%20subtitles.srt', 'file_name': 'Huo Meng Hua - Flying guillotine english subtitles.srt', 'requests': 228, 'remaining': 772, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648984 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648984}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Hot.Property.2016.720p.WEB-DL.XviD.AC3-FGT-(Italic%20Free).srt', 'file_name': 'My.Hot.Property.2016.720p.WEB-DL.XviD.AC3-FGT-(Italic Free).srt', 'requests': 229, 'remaining': 771, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648984 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648984}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20Trek%20TNG%20-%20Special%20Feature%20-%20Making%20of%20a%20Legend-eng.srt', 'file_name': 'Star Trek TNG - Special Feature - Making of a Legend-eng.srt', 'requests': 230, 'remaining': 770, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648985 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648985}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....TamilMV.bid%20-%20Uyare%20(2019)%20Malayalam%20Original%20HQ%20DVDRip%20-%20720p%20-%20x264%20-%20(DD+5.1%20-%20224K.srt', 'file_name': 'www.TamilMV.bid - Uyare (2019) Malayalam Original HQ DVDRip - 720p - x264 - (DD+5.1 - 224K.srt', 'requests': 231, 'remaining': 769, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648985 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648985}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20Yoga%20-%20The%20Architecture%20of%20Peace%20(2017)%20900p%20WEB%20x264%20Dr3adLoX.ENG.srt', 'file_name': 'On Yoga - The Architecture of Peace (2017) 900p WEB x264 Dr3adLoX.ENG.srt', 'requests': 232, 'remaining': 768, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648985 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648985}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20(2017)%20Kannada%20720p%20HDRip%20AC3%205.1%20x264%201.4GB%20ESubs.srt', 'file_name': 'Ayana (2017) Kannada 720p HDRip AC3 5.1 x264 1.4GB ESubs.srt', 'requests': 233, 'remaining': 767, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648986 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648986}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Remember.You.2017.720p.BluRay.x264-HANDJOB.srt', 'file_name': 'I.Remember.You.2017.720p.BluRay.x264-HANDJOB.srt', 'requests': 234, 'remaining': 766, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648986 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648986}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....2020.WEBRip.x264-ION10.srt', 'file_name': 'Roped.2020.WEBRip.x264-ION10.srt', 'requests': 235, 'remaining': 765, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648987 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648987}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Star.Christmas.2018.HDRip.XviD.AC3-EVO.srt', 'file_name': 'Puppy.Star.Christmas.2018.HDRip.XviD.AC3-EVO.srt', 'requests': 236, 'remaining': 764, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648987 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648987}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Incomplete.2020.720p.WEBRip.x264.AAC-%5BYTS.MX%5D.srt', 'file_name': 'T11.Incomplete.2020.720p.WEBRip.x264.AAC-[YTS.MX].srt', 'requests': 237, 'remaining': 763, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648988 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648988}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....allem.2019.GERMAN.DL.1080P.WEBRip.X264-WAYNE_eng.srt', 'file_name': 'Trotz.allem.2019.GERMAN.DL.1080P.WEBRip.X264-WAYNE_eng.srt', 'requests': 238, 'remaining': 762, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648988 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648988}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20Land%20(2011)%20BluRay_English.srt', 'file_name': 'Ladda Land (2011) BluRay_English.srt', 'requests': 239, 'remaining': 761, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648988 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648988}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles...._(2017)_Nepali_720p_WEB-DL_x264_AC3_5.1_ESub-Sun_George.srt', 'file_name': 'Pahuna_(2017)_Nepali_720p_WEB-DL_x264_AC3_5.1_ESub-Sun_George.srt', 'requests': 240, 'remaining': 760, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648989 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648989}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....WEBRip.Netflix.en.srt', 'file_name': 'NiNoKuni.WEBRip.Netflix.en.srt', 'requests': 241, 'remaining': 759, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648989 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648989}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Very.Own.Christmas.Story.1978.1080p.NF.WEB-DL.DD2.0.x264-AJP69.srt', 'file_name': 'Benjis.Very.Own.Christmas.Story.1978.1080p.NF.WEB-DL.DD2.0.x264-AJP69.srt', 'requests': 242, 'remaining': 758, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648989 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648989}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....srt', 'file_name': 'en.srt', 'requests': 243, 'remaining': 757, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648990 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648990}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20a%20Shot%20at%20Love%202021%20Hallmark%20720p%20HDTV%20X264%20Solar.srt', 'file_name': 'Taking a Shot at Love 2021 Hallmark 720p HDTV X264 Solar.srt', 'requests': 244, 'remaining': 756, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648990 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648990}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....People.1980.DVDRip.DivX-CLiX.srt', 'file_name': 'Ordinary.People.1980.DVDRip.DivX-CLiX.srt', 'requests': 245, 'remaining': 755, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648991 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648991}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....1986.1080p.BrRip.x264.YIFY.srt', 'file_name': 'Platoon.1986.1080p.BrRip.x264.YIFY.srt', 'requests': 246, 'remaining': 754, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648991 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648991}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Tu.Ya.Jaane.Na.2008.DVDRip.XviD-BrG.srt', 'file_name': 'Jaane.Tu.Ya.Jaane.Na.2008.DVDRip.XviD-BrG.srt', 'requests': 247, 'remaining': 753, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648992 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648992}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Crimes.2017.720p.WEBRip.XviD.AC3-FGT.srt', 'file_name': 'Small.Crimes.2017.720p.WEBRip.XviD.AC3-FGT.srt', 'requests': 248, 'remaining': 752, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648993 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648993}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Place.in.the.Stars.2014.1080p.WEBRip.x264-RARBG.srt', 'file_name': 'A.Place.in.the.Stars.2014.1080p.WEBRip.x264-RARBG.srt', 'requests': 249, 'remaining': 751, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648994 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648994}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%20Me%201992%20DVDRip%20XviD%20SUPREME%20(700MB).srt', 'file_name': 'American Me 1992 DVDRip XviD SUPREME (700MB).srt', 'requests': 250, 'remaining': 750, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648995 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648995}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Fungi.2019.1080p.WEB-DL.AAC2.0.srt', 'file_name': 'Fantastic.Fungi.2019.1080p.WEB-DL.AAC2.0.srt', 'requests': 251, 'remaining': 749, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648995 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648995}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Zookeepers.Wife.2017.1080p.BluRay.x264-GECKOS.srt', 'file_name': 'The.Zookeepers.Wife.2017.1080p.BluRay.x264-GECKOS.srt', 'requests': 252, 'remaining': 748, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-14 00:00:00 UTC) ts=1686648996 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-14T00:00:00.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648996}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Star.2017.WEB-DL.x264-FGT.srt', 'file_name': 'Frat.Star.2017.WEB-DL.x264-FGT.srt', 'requests': 253, 'remaining': 747, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648996 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648996}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles.....Wars.I.The.Phantom.Menace%5B1999%5DDVDrip-aXXo.srt', 'file_name': 'Star.Wars.I.The.Phantom.Menace[1999]DVDrip-aXXo.srt', 'requests': 254, 'remaining': 746, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648996 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648996}
# Report: <Response [200]>
# {'link': 'https://www.opensubtitles....%204%20-%20The%20Legend%20Begins.srt', 'file_name': 'Tremors 4 - The Legend Begins.srt', 'requests': 255, 'remaining': 745, 'message': 'Your quota will be renewed in 14 hours and 23 minutes (2023-06-13 23:59:59 UTC) ts=1686648997 ', 'reset_time': '14 hours and 23 minutes', 'reset_time_utc': '2023-06-13T23:59:59.000Z', 'uk': 'count_uid_459397', 'uid': 459397, 'ts': 1686648997}

# %% [markdown]
# ## Clean subtitle files
# The subtitle files from opensubtitles come in the SRT (SubRip Subtitle) file format by default, which includes start and end timecodes to ensure the subtitles match the audio. For our use case, however, we do not need this information.
#
# For example, the original files look like this:
# ```
# 1
# 00:01:33,877 --> 00:01:35,276
# Amanda!
#
# 2
# 00:01:38,681 --> 00:01:40,649
# Amanda, turn that down!
# ```
#
# And we want to convert it to this:
# ```
# Amanda!
# Amanda, turn that down!
# ```
#
# To clean the subtitles from this extra information, I used a python script by Nat Dunn (2017), 'Simple Python Script for Extracting Text from an SRT File', link: https://gist.github.com/ndunn219/62263ce1fb59fda08656be7369ce329b
#
# I simply loaded it into this notebook by using:
# ```
# %load srt_to_txt.py
# ```

# %%
##script by Nat Dunn, link: https://gist.github.com/natdunn/4d4c8a2c1a1f0e5c4c0d

# %load srt_to_txt.py
"""
Creates readable text file from SRT file.
"""
import re, sys

def is_time_stamp(l):
  if l[:2].isnumeric() and l[2] == ':':
    return True
  return False

def has_letters(line):
  if re.search('[a-zA-Z]', line):
    return True
  return False

def has_no_text(line):
  l = line.strip()
  if not len(l):
    return True
  if l.isnumeric():
    return True
  if is_time_stamp(l):
    return True
  if l[0] == '(' and l[-1] == ')':
    return True
  if not has_letters(line):
    return True
  return False

def is_lowercase_letter_or_comma(letter):
  if letter.isalpha() and letter.lower() == letter:
    return True
  if letter == ',':
    return True
  return False

def clean_up(lines):
  """
  Get rid of all non-text lines and
  try to combine text broken into multiple lines
  """
  new_lines = []
  for line in lines[1:]:
    if has_no_text(line):
      continue
    elif len(new_lines) and is_lowercase_letter_or_comma(line[0]):
      #combine with previous line
      new_lines[-1] = new_lines[-1].strip() + ' ' + line
    else:
      #append line
      new_lines.append(line)
  return new_lines

def main(args):
  """
    args[1]: file name
    args[2]: encoding. Default: utf-8.
      - If you get a lot of [?]s replacing characters,
      - you probably need to change file_encoding to 'cp1252'
  """
  file_name = args[1]
  file_encoding = 'utf-8' if len(args) < 3 else args[2]
  with open(file_name, encoding=file_encoding, errors='replace') as f:
    lines = f.readlines()
    new_lines = clean_up(lines)
  new_file_name = file_name[:-4] + '.txt'
  with open(new_file_name, 'w') as f:
    for line in new_lines:
      f.write(line)

if __name__ == '__main__':
  main(sys.argv)

"""
NOTES
 * Run from command line as
 ** python srt_to_txt.py file_name.srt cp1252
 * Creates file_name.txt with extracted text from file_name.srt 

 * Script assumes that lines beginning with lowercase letters or commas 
 * are part of the previous line and lines beginning with any other character
 * are new lines. This won't always be correct. 
"""

# %%
## The code in this cell is from the user chetankhanna767 on GeeksforGeeks (2021), 'How to iterate over files in directory using Python?', link: https://www.geeksforgeeks.org/how-to-iterate-over-files-in-directory-using-python/
## modified to work with the main function from the python script above

#assign directory
directory = 'data/subtitles'
 
#iterate over files in that directory
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    #print(file_path)
    main( ['', file_path, 'utf-8']) #use the main() function from the python script above with each subtitle file

# %% [markdown]
# ### Hand-Curation
# After running this script, I went through all the downloaded subtitles to see if everything looked right.
#
# In doing so, I noticed that some files still contained tags, like `<font colour="white">`, or other text symbols, like `#`. Since this is not part of the text body we want to analyse, I compiled all the symbols I found into a list and deleted them from the files:

# %%
##The code in this cell was written by ChatGPT after being given the list of symbols and some sample text strings

#Create regex pattern to remove symbols from text
def remove_symbols(text):
    symbols = ['</i>', '<i>', '-', '[', ']', '♪', '"', '<font color="#ffff00">', '<font color=00ffff>','<font color=#FFFF00>', '<font color="#00ff00">', '<font color="#D900D9">', '</font>', '<font color="white">', '#', '<span style="style.default_1">', '</span>', '%%', '{\\an8}', '*', '¶', '♫', "''", '{y:i}', '<font face=Californian FB>','<b>', '</b>', "{F:Verdana}{S:14}{C:$FFFFFF}"]
    pattern = re.compile('|'.join(map(re.escape, symbols)))
    return re.sub(pattern, '', text)

# %%
#assign directory
directory = 'data/subtitles'

#iterate over files in that directory
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)

    #open and read the subtitle txt file
    with open(file_path, 'r') as f:
        content = f.read()
        
    #clean and save the subtitle text
    with open(file_path, 'w') as f:
        content = remove_symbols(content)
        f.write(content)

# %% [markdown]
# While looking through all the subtitle files, I also noticed that some of them only include a few lines of text. So I checked to see if they had another version of the subtitles directly on opensubtitles.com.
#
# This affected the following titles:
#
# - Bombshell: The Hedy Lamarr Story
# - Counterpunch
# - **Oloibiri**
# - **Sitara: Let Girls Dream**
# - **Spirit Riding Free: Ride Along Adventure**
# - The Ivory Game
# - Without Gorky
# - **Oddbods: Party Monsters**
#
# There were no alternatives for the titles marked in **bold**, so I decided to delete them from the data set. The subtitles for the other four films were replaced - the problem with these was that the original files only contained the subtitles for foreign parts.

# %%
#Delete the mentioned titles from the df
delete_titles = ['Oloibiri', 'Sitara: Let Girls Dream', 'Spirit Riding Free: Ride Along Adventure','Oddbods: Party Monsters']
df = df[df.title.isin(delete_titles) == False]
#reset index
df.reset_index(drop=True,inplace=True)
#check if it worked (should be reduced from 1904 to 1900 movies)
len(df)
# Out:
# 1900

# %% [markdown]
# ## Include subtitles in df
# As a final step, simply because I prefer to collect all the data in a single dataframe, I added the subtitles to our existing df.

# %%
#create a new empty df where we will safe the subtitles in
df_subtitles = pd.DataFrame(columns=['title', 'subtitle'])
df_subtitles
# Out:
# Empty DataFrame
# Columns: [title, subtitle]
# Index: []

# %%
directory = 'data/subtitles'
#iterate through all files in the directory
for filename in os.listdir(directory):
    df_new = pd.DataFrame({'title': [''], 'subtitle':['']}) #create a new df
    df_new['title'] = filename.split(".txt")[0] #save the movie title (which is the filename) in the df
    file_path = os.path.join(directory, filename)
    #print(filename.split(".")[0])
    with open(file_path,'r') as f:
        contents = f.read().replace('\n', ' ') #read the file and replace all line breaks with spaces
        df_new['subtitle'] = contents #save the subtitles in the df
    df_subtitles= pd.concat([df_subtitles,df_new]) #add the new df to the df with all subtitles

# %%
#reset index of df_subtitles
df_subtitles = df_subtitles.reset_index(drop=True)
df_subtitles = df_subtitles.drop(872, axis=0)
df_subtitles
# Out:
#                                title  \
# 0                     The Ivory Game
# 1            You're Everything To Me
# 2                      The 8th Night
# 3                         St. Agatha
# 4                         Isi & Ossi
# ...                              ...
# 1896               WHAT DID JACK DO?
# 1897  Killer Klowns from Outer Space
# 1898                The Lost Husband
# 1899                 Lady Bloodfight
# 1900             The End of the Tour
#
#                                                subtitle
# 0     Shetani the Devil has taken over, taken over t...
# 1     Announcer Major General McCourtney entering. S...
# 2     2,500 years ago, a monster started opening the...
# 3      Help me! Help, somebody help get me out of he...
# 4     narrator This is Heidelberg, the Heidelberg Ca...
# ...                                                 ...
# 1896  So, we meet in a train station. Jack. You know...
# 1897  Transcript by rogard custommade for simonhawki...
# 1898  Is that Marsha's sister? What do we call her? ...
# 1899  LADY BLOOD FIGHT HONG KONG 5 years ago Stop th...
# 1900   Hey. Bob, what's up?  Hi. Listen. According t...
#
# [1900 rows x 2 columns]

# %%
#merge df_subtitles with df
df_merged = pd.merge(df, df_subtitles, on='title', how='outer')
df_merged
# Out:
#                                       title  \
# 0                      The Last Blockbuster
# 1     Franco Escamilla: Bienvenido al mundo
# 2                              Last Knights
# 3                                Win It All
# 4                           Freedom Writers
# ...                                     ...
# 1895                        Fantastic Fungi
# 1896                   The Zookeeper's Wife
# 1897                              Frat Star
# 1898                               Star Men
# 1899           Tremors 4: The Legend Begins
#
#                                           listed_in  \
# 0                                     Documentaries
# 1                                   Stand-Up Comedy
# 2                                Action & Adventure
# 3     Comedies, Independent Movies, Romantic Movies
# 4                                            Dramas
# ...                                             ...
# 1895                                  Documentaries
# 1896                                         Dramas
# 1897                                       Comedies
# 1898                                  Documentaries
# 1899      Comedies, Horror Movies, Sci-Fi & Fantasy
#
#                             director  \
# 0                      Taylor Morden
# 1                    Ulises Valencia
# 2                     Kazuaki Kiriya
# 3                       Joe Swanberg
# 4                Richard LaGravenese
# ...                              ...
# 1895              Louie Schwartzberg
# 1896                       Niki Caro
# 1897  Grant S. Johnson, Ippsie Jones
# 1898                  Alison E. Rose
# 1899                     S.S. Wilson
#
#                                                    cast  \
# 0                                                   NaN
# 1                                      Franco Escamilla
# 2     Clive Owen, Morgan Freeman, Cliff Curtis, Akse...
# 3     Jake Johnson, Aislinn Derbez, Joe Lo Truglio, ...
# 4     Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# ...                                                 ...
# 1895                                                NaN
# 1896  Jessica Chastain, Johan Heldenbergh, Daniel Br...
# 1897  Connor Lawrence, Justin Mark, Cathryn Dylan, C...
# 1898                                                NaN
# 1899  Michael Gross, Sara Botsford, Billy Drago, Bre...
#
#                                             description   imdb_id  \
# 0     This nostalgic documentary reveals the real st...   8704802
# 1     Comedian Franco Escamilla shares stories about...  10128616
# 2     A nobleman who values his people's well-being ...   2493486
# 3     After losing $50,000 that wasn't his, gambling...   3155328
# 4     While her at-risk students are reading classic...    463998
# ...                                                 ...       ...
# 1895  Delve into the magical world of fungi, from mu...   8258074
# 1896  When the Nazis invade Poland, Warsaw Zoo caret...   1730768
# 1897  A freshman uninterested in joining a fraternit...   5117484
# 1898  Four astronomers from England celebrate 50 yea...    120915
# 1899  Residents of a abandoned mining town attempt t...    334541
#
#       opensubtitle_id                                           subtitle
# 0           7101681.0  Downloaded from YTS.MX Official YIFY movies si...
# 1           6649312.0  It's a great honor to be here, to introduce yo...
# 2           1123612.0  During the long, dark period of the Great Wars...
# 3           1197968.0  Cubs parking! Easy entry and exit! How is it g...
# 4           3537643.0  There have been shots fired. Total civil unres...
# ...               ...                                                ...
# 1895        6603481.0  Subtitles by explosiveskull www.OpenSubtitles....
# 1896        1183737.0  ANTONINA: Hello, Jerzyk. JERZYK: Good morning,...
# 1897        1184644.0  Hey! You piece of shit. We were having some fu...
# 1898         247903.0  subversive subs presents Star Wars: Episode I ...
# 1899         411345.0  Awful soft dirt in here. Make sure you shore i...
#
# [1900 rows x 8 columns]

# %%
#delete imdb_id and opensubtitle_id columns as we don't need them anymore
df_merged = df_merged.drop(['imdb_id', 'opensubtitle_id'], axis=1)
df_merged.head(3)
# Out:
#                                    title           listed_in         director  \
# 0                   The Last Blockbuster       Documentaries    Taylor Morden
# 1  Franco Escamilla: Bienvenido al mundo     Stand-Up Comedy  Ulises Valencia
# 2                           Last Knights  Action & Adventure   Kazuaki Kiriya
#
#                                                 cast  \
# 0                                                NaN
# 1                                   Franco Escamilla
# 2  Clive Owen, Morgan Freeman, Cliff Curtis, Akse...
#
#                                          description  \
# 0  This nostalgic documentary reveals the real st...
# 1  Comedian Franco Escamilla shares stories about...
# 2  A nobleman who values his people's well-being ...
#
#                                             subtitle
# 0  Downloaded from YTS.MX Official YIFY movies si...
# 1  It's a great honor to be here, to introduce yo...
# 2  During the long, dark period of the Great Wars...

# %%
#save as a new .csv file
df_merged.to_csv('data/netflix_with_subtitles.csv')

# %% [markdown]
# It should be mentioned that there is no 100% guarantee that all subtitles are correct. This is for two reasons:
# - The files on opensubtitles.com are uploaded by users and could be faults
# - I always simply used the first IMDB ID that was suggested. So if there are several movies with exactly the same title, it is possible that the subtitles were downloaded for the wrong movie.
